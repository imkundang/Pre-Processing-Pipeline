# %%
import pandas as pd

# %%
#df=pd.read_csv("PS_20174392719_1491204439457_log.csv")

# %%
df=pd.read_csv('train_v2.csv')
# Out:
# C:\Users\satish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (135,204,274,417) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    id   f1  f2        f3    f4  f5     f6      f7      f8      f9  ...  f770  \
# 0   1  126  10  0.686842  1100   3  13699  7201.0  4949.0  126.75  ...     5
# 1   2  121  10  0.782776  1100   3  84645   240.0  1625.0  123.52  ...     6
# 2   3  126  10  0.500080  1100   3  83607  1800.0  1527.0  127.76  ...    13
# 3   4  134  10  0.439874  1100   3  82642  7542.0  1730.0  132.94  ...     4
# 4   5  109   9  0.502749  2900   4  79124    89.0   491.0  122.72  ...    26
#
#    f771  f772  f773    f774    f775  f776  f777  f778  loss
# 0  2.14 -1.54  1.18  0.1833  0.7873     1     0     5     0
# 1  0.54 -0.24  0.13  0.1926 -0.6787     1     0     5     0
# 2  2.89 -1.73  1.04  0.2521  0.7258     1     0     5     0
# 3  1.29 -0.89  0.66  0.2498  0.7119     1     0     5     0
# 4  6.11 -3.82  2.51  0.2282 -0.5399     0     0     5     0
#
# [5 rows x 771 columns]

# %%
df.dtypes
# Out:
# id        int64
# f1        int64
# f2        int64
# f3      float64
# f4        int64
#          ...
# f775    float64
# f776      int64
# f777      int64
# f778      int64
# loss      int64
# Length: 771, dtype: object

# %%
def data_shape(data):
    # find the shape of data
    shape=data.shape
    rows = data.shape[0]
    col= data.shape[1]
    return {'shape of data':shape, 'number of rows':rows, 'number of features':col }

data_shape(df)
# Out:
# {'shape of data': (105471, 771),
#  'number of rows': 105471,
#  'number of features': 771}

# %%
def nullcount(data):
    total=(data.isnull().sum()).sort_values(ascending=False)
    percentage=((data.isnull().sum())/(data.isnull().count())*100).sort_values(ascending=False)
    datatype=data.dtypes
    ms=pd.concat([total,percentage,datatype],axis=1,keys=['Total','Percentage','Datatype'])
    ms=ms[ms['Percentage']>0]
    return ms

nullcount(df)
# Out:
#       Total  Percentage Datatype
# f663  18833   17.856093  float64
# f662  18833   17.856093  float64
# f159  18736   17.764125  float64
# f160  18736   17.764125  float64
# f169  18417   17.461672  float64
# ...     ...         ...      ...
# f765      1    0.000948  float64
# f675      1    0.000948  float64
# f676      1    0.000948  float64
# f677      1    0.000948  float64
# f678      1    0.000948  float64
#
# [525 rows x 3 columns]

# %%
def finddtye(data):
    intcount=0
    floatcount=0
    objectcount=0
    for name,datatype in data.dtypes.iteritems():
        if datatype=='float64':
            floatcount=floatcount+1
        elif datatype=='int64':
            intcount=intcount+1
        else:
            objectcount=objectcount+1
    df=pd.DataFrame({'IntegerType':[intcount],'Float Type':[floatcount],'Object Type':[objectcount]})
    df['Total Features']=df['IntegerType']+df['Object Type']+df['Float Type']
    return df
finddtye(df)
# Out:
#    IntegerType  Float Type  Object Type  Total Features
# 0           99         653           19             771

# %%
#to drop selected columns object datatypes
'''def dropcolumns(data):
    for i in ['step']:
        data.drop(i,axis=1,inplace=True)
dropcolumns(df)'''
# Out:
# "def dropcolumns(data):\n    for i in ['step']:\n        data.drop(i,axis=1,inplace=True)\ndropcolumns(df)"

# %%
#let's findout unique value in each of categorical variables
def col_enc(data):
    for col in data.select_dtypes(include=['object']).columns:
        print(col, ':' , len(data[col].unique()), 'labels')
col_enc(df)
# Out:
# f137 : 6551 labels
# f138 : 31152 labels
# f206 : 20087 labels
# f207 : 14511 labels
# f276 : 6041 labels
# f277 : 28710 labels
# f338 : 8663 labels
# f390 : 104662 labels
# f391 : 104659 labels
# f419 : 24826 labels
# f420 : 25772 labels
# f469 : 86420 labels
# f472 : 102913 labels
# f534 : 85376 labels
# f537 : 104114 labels
# f626 : 104754 labels
# f627 : 104751 labels
# f695 : 93730 labels
# f698 : 91986 labels

# %%
def dropcolumns(data):
    for i in data.select_dtypes(include=['object']).columns:
        data.drop(i,axis=1,inplace=True)
dropcolumns(df)

# %%
df.head()
# Out:
#    id   f1  f2        f3    f4  f5     f6      f7      f8      f9  ...  f770  \
# 0   1  126  10  0.686842  1100   3  13699  7201.0  4949.0  126.75  ...     5
# 1   2  121  10  0.782776  1100   3  84645   240.0  1625.0  123.52  ...     6
# 2   3  126  10  0.500080  1100   3  83607  1800.0  1527.0  127.76  ...    13
# 3   4  134  10  0.439874  1100   3  82642  7542.0  1730.0  132.94  ...     4
# 4   5  109   9  0.502749  2900   4  79124    89.0   491.0  122.72  ...    26
#
#    f771  f772  f773    f774    f775  f776  f777  f778  loss
# 0  2.14 -1.54  1.18  0.1833  0.7873     1     0     5     0
# 1  0.54 -0.24  0.13  0.1926 -0.6787     1     0     5     0
# 2  2.89 -1.73  1.04  0.2521  0.7258     1     0     5     0
# 3  1.29 -0.89  0.66  0.2498  0.7119     1     0     5     0
# 4  6.11 -3.82  2.51  0.2282 -0.5399     0     0     5     0
#
# [5 rows x 752 columns]

# %%
#dummies=pd.get_dummies(df.type,drop_first=True)

# %%
#df=df.join(dummies)

# %%
df.shape
# Out:
# (105471, 752)

# %%
def filldata(data):
    for name,datatype in data.dtypes.iteritems():
        if datatype=='float64':
            print(name)
            data.fillna(data[name].median(),inplace=True)
        elif datatype=='int64':
            print(name)
            data.fillna(data[name].mean(),inplace=True)

# %%
filldata(df)
# Out:
# id
# f1
# f2
# f3
# f4
# f5
# f6
# f7
# f8
# f9
# f10
# f13
# f14
# f15
# f16
# f17
# f18
# f19
# f20
# f21
# f22
# f23
# f24
# f25
# f26
# f27
# f28
# f29
# f30
# f31
# f32
# f33
# f34
# f35
# f36
# f37
# f38
# f39
# f40
# f41
# f42
# f43
# f44
# f45
# f46
# f47
# f48
# f49
# f50
# f51
# f52
# f53
# f54
# f55
# f56
# f57
# f58
# f59
# f60
# f61
# f62
# f63
# f64
# f65
# f66
# f67
# f68
# f69
# f70
# f71
# f72
# f73
# f74
# f75
# f76
# f77
# f78
# f79
# f80
# f81
# f82
# f83
# f84
# f85
# f86
# f87
# f88
# f89
# f90
# f91
# f92
# f93
# f94
# f95
# f96
# f97
# f98
# f99
# f100
# f101
# f102
# f103
# f104
# f105
# f106
# f107
# f108
# f109
# f110
# f111
# f112
# f113
# f114
# f115
# f116
# f117
# f118
# f119
# f120
# f121
# f122
# f123
# f124
# f125
# f126
# f127
# f128
# f129
# f130
# f131
# f132
# f133
# f134
# f135
# f136
# f139
# f140
# f141
# f142
# f143
# f144
# f145
# f146
# f147
# f148
# f149
# f150
# f151
# f152
# f153
# f154
# f155
# f156
# f157
# f158
# f159
# f160
# f161
# ...

# %%
#https://www.kaggle.com/dhyaks/loan-default-prediction-in-easy-way-akshay/notebook

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
def data_split(data):
    X=data.iloc[:,:-1]
    y=data['loss']
    x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=5,test_size=.3)
    sc=StandardScaler()
    x_train=sc.fit_transform(x_train)
    x_test=sc.transform(x_test)

    return x_train,x_test,y_train,y_test

# %%
#data_split(df)

# %%
x_train.shape
# Out:
# (73829, 751)

# %%
y_train.shape
# Out:
# (73829,)

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
type(x_train)
# Out:
# numpy.ndarray
